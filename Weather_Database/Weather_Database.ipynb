# %%
import requests
from citipy import citipy 

# Import the API key.
from config import weather_api_key

from datetime import datetime
import numpy as np
import time
import pandas as pd

# %%
#Prepare Coordinates

def generateLats_longs(size):
    
    latitudes = np.random.uniform(-90,90,size)
    longitudes = np.random.uniform(-180,180,size)

    return zip(latitudes,longitudes)

# %%
#intialise a city series object
city_Data=[]

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key


# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


coordinates=  generateLats_longs(500)
cities =[]

for coordinate in coordinates:
    cities.append(citipy.nearest_city(coordinate[0], coordinate[1]).city_name)

print(len(cities))


for i , city in enumerate(cities):
    
     # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(city_url)
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
      
        city_lng = city_weather["coord"]["lon"]
       
        city_max_temp = city_weather["main"]["temp_max"]
        
        city_humidity = city_weather["main"]["humidity"]
        
        city_clouds = city_weather["clouds"]["all"]
       
        city_wind = city_weather["wind"]["speed"]
        
        city_country = city_weather["sys"]["country"]
       
        city_weatherDesc = city_weather["weather"][0]["description"]
      
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_Data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                           "Current Description":city_weatherDesc})

        
        # If an error is experienced, skip the city.
    except BaseException as e:
        print(e)        
        print("City not found. Skipping..." + city)
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
    
# print(city_url)
city_Data_df = pd.DataFrame(city_Data)
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_Data_df.to_csv(output_data_file, index_label="City_ID")



#save the results in csv
# Out:
# Beginning Data Retrieval
# -----------------------------
# 500
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=ilulissat
# Processing Record 1 of Set 1 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=chuy
# Processing Record 2 of Set 1 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hami
# Processing Record 3 of Set 1 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=puerto+ayora
# Processing Record 4 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kerki
# Processing Record 5 of Set 1 | kerki
# 'coord'
# City not found. Skipping...kerki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hermanus
# Processing Record 6 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=labuhan
# Processing Record 7 of Set 1 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kruisfontein
# Processing Record 8 of Set 1 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=khandyga
# Processing Record 9 of Set 1 | khandyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=taolanaro
# Processing Record 10 of Set 1 | taolanaro
# 'coord'
# City not found. Skipping...taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=port+hedland
# Processing Record 11 of Set 1 | port hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=punta+arenas
# Processing Record 12 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=takoradi
# Processing Record 13 of Set 1 | takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=prado
# Processing Record 14 of Set 1 | prado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=cody
# Processing Record 15 of Set 1 | cody
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=taiyuan
# Processing Record 16 of Set 1 | taiyuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=carnarvon
# Processing Record 17 of Set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=nabire
# Processing Record 18 of Set 1 | nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=san+patricio
# Processing Record 19 of Set 1 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=ostashkov
# Processing Record 20 of Set 1 | ostashkov
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=ribeira+grande
# Processing Record 21 of Set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=castro
# Processing Record 22 of Set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=khatanga
# Processing Record 23 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=belushya+guba
# Processing Record 24 of Set 1 | belushya guba
# 'coord'
# City not found. Skipping...belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=chokurdakh
# Processing Record 25 of Set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=esso
# Processing Record 26 of Set 1 | esso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=avera
# Processing Record 27 of Set 1 | avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=tiksi
# Processing Record 28 of Set 1 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=haines+junction
# Processing Record 29 of Set 1 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=esperance
# Processing Record 30 of Set 1 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=henties+bay
# Processing Record 31 of Set 1 | henties bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=bethel
# Processing Record 32 of Set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hermanus
# Processing Record 33 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=qaanaaq
# Processing Record 34 of Set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=taolanaro
# Processing Record 35 of Set 1 | taolanaro
# 'coord'
# City not found. Skipping...taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=caohai
# Processing Record 36 of Set 1 | caohai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=yulara
# Processing Record 37 of Set 1 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=encarnacion
# Processing Record 38 of Set 1 | encarnacion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=okato
# Processing Record 39 of Set 1 | okato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=porto+novo
# Processing Record 40 of Set 1 | porto novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=naftah
# Processing Record 41 of Set 1 | naftah
# 'coord'
# City not found. Skipping...naftah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=victoria
# Processing Record 42 of Set 1 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=albany
# Processing Record 43 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=rio+gallegos
# Processing Record 44 of Set 1 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=payo
# Processing Record 45 of Set 1 | payo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=letlhakane
# Processing Record 46 of Set 1 | letlhakane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=adre
# Processing Record 47 of Set 1 | adre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=rikitea
# Processing Record 48 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=norman+wells
# Processing Record 49 of Set 1 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=chokurdakh
# Processing Record 50 of Set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=busselton
# Processing Record 1 of Set 2 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=talnakh
# Processing Record 2 of Set 2 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=ulenje
# Processing Record 3 of Set 2 | ulenje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=ushuaia
# Processing Record 4 of Set 2 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=mys+shmidta
# Processing Record 5 of Set 2 | mys shmidta
# 'coord'
# City not found. Skipping...mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=bakchar
# Processing Record 6 of Set 2 | bakchar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=atuona
# Processing Record 7 of Set 2 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kieta
# Processing Record 8 of Set 2 | kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hofn
# Processing Record 9 of Set 2 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=sioux+lookout
# Processing Record 10 of Set 2 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=qaanaaq
# Processing Record 11 of Set 2 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=attawapiskat
# Processing Record 12 of Set 2 | attawapiskat
# 'coord'
# City not found. Skipping...attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hilo
# Processing Record 13 of Set 2 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=yellowknife
# Processing Record 14 of Set 2 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=faanui
# Processing Record 15 of Set 2 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hervey+bay
# Processing Record 16 of Set 2 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=humaita
# Processing Record 17 of Set 2 | humaita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=eureka
# Processing Record 18 of Set 2 | eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=homer
# Processing Record 19 of Set 2 | homer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=mys+shmidta
# Processing Record 20 of Set 2 | mys shmidta
# 'coord'
# City not found. Skipping...mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=karasburg
# Processing Record 21 of Set 2 | karasburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=faanui
# Processing Record 22 of Set 2 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=sitka
# Processing Record 23 of Set 2 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=bredasdorp
# Processing Record 24 of Set 2 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=rikitea
# Processing Record 25 of Set 2 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=rikitea
# Processing Record 26 of Set 2 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=mataura
# Processing Record 27 of Set 2 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=fortuna
# Processing Record 28 of Set 2 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=komsomolskiy
# Processing Record 29 of Set 2 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kloulklubed
# Processing Record 30 of Set 2 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hilo
# Processing Record 31 of Set 2 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=flinders
# Processing Record 32 of Set 2 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=bengkulu
# Processing Record 33 of Set 2 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kapaa
# Processing Record 34 of Set 2 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=pisco
# Processing Record 35 of Set 2 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=tuktoyaktuk
# Processing Record 36 of Set 2 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=rikitea
# Processing Record 37 of Set 2 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=cotonou
# Processing Record 38 of Set 2 | cotonou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=lebu
# Processing Record 39 of Set 2 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=castro
# Processing Record 40 of Set 2 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=ushuaia
# Processing Record 41 of Set 2 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=ushuaia
# Processing Record 42 of Set 2 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=burns+lake
# Processing Record 43 of Set 2 | burns lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=rio+grande
# Processing Record 44 of Set 2 | rio grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=nizhneyansk
# Processing Record 45 of Set 2 | nizhneyansk
# 'coord'
# City not found. Skipping...nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=barrow
# Processing Record 46 of Set 2 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=souillac
# Processing Record 47 of Set 2 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=dandong
# Processing Record 48 of Set 2 | dandong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=ponta+do+sol
# Processing Record 49 of Set 2 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=balkanabat
# Processing Record 50 of Set 2 | balkanabat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=khatanga
# Processing Record 1 of Set 3 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kapaa
# Processing Record 2 of Set 3 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=cabedelo
# Processing Record 3 of Set 3 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=rikitea
# Processing Record 4 of Set 3 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=oxford
# Processing Record 5 of Set 3 | oxford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=waddan
# Processing Record 6 of Set 3 | waddan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=matay
# Processing Record 7 of Set 3 | matay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=bredasdorp
# Processing Record 8 of Set 3 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=eureka
# Processing Record 9 of Set 3 | eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=port+alfred
# Processing Record 10 of Set 3 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=mahebourg
# Processing Record 11 of Set 3 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=rikitea
# Processing Record 12 of Set 3 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=leshukonskoye
# Processing Record 13 of Set 3 | leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=league+city
# Processing Record 14 of Set 3 | league city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=palasa
# Processing Record 15 of Set 3 | palasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=atar
# Processing Record 16 of Set 3 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kodiak
# Processing Record 17 of Set 3 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=marcona
# Processing Record 18 of Set 3 | marcona
# 'coord'
# City not found. Skipping...marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=sechura
# Processing Record 19 of Set 3 | sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=chokurdakh
# Processing Record 20 of Set 3 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=shieli
# Processing Record 21 of Set 3 | shieli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=bambous+virieux
# Processing Record 22 of Set 3 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=vardo
# Processing Record 23 of Set 3 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hermanus
# Processing Record 24 of Set 3 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=georgetown
# Processing Record 25 of Set 3 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=pandan
# Processing Record 26 of Set 3 | pandan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hasaki
# Processing Record 27 of Set 3 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=rikitea
# Processing Record 28 of Set 3 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=sentyabrskiy
# Processing Record 29 of Set 3 | sentyabrskiy
# 'coord'
# City not found. Skipping...sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=manakara
# Processing Record 30 of Set 3 | manakara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kailaras
# Processing Record 31 of Set 3 | kailaras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=lasa
# Processing Record 32 of Set 3 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hilo
# Processing Record 33 of Set 3 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=puerto+ayora
# Processing Record 34 of Set 3 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=rurrenabaque
# Processing Record 35 of Set 3 | rurrenabaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=andijon
# Processing Record 36 of Set 3 | andijon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hermanus
# Processing Record 37 of Set 3 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=fortuna
# Processing Record 38 of Set 3 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=carutapera
# Processing Record 39 of Set 3 | carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=attawapiskat
# Processing Record 40 of Set 3 | attawapiskat
# 'coord'
# City not found. Skipping...attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=tecoanapa
# Processing Record 41 of Set 3 | tecoanapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=constitucion
# Processing Record 42 of Set 3 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=thompson
# Processing Record 43 of Set 3 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=castro
# Processing Record 44 of Set 3 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=butaritari
# Processing Record 45 of Set 3 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hobart
# Processing Record 46 of Set 3 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=tiksi
# Processing Record 47 of Set 3 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=santa+maria
# Processing Record 48 of Set 3 | santa maria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=scarborough
# Processing Record 49 of Set 3 | scarborough
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=mataura
# Processing Record 50 of Set 3 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=gogrial
# Processing Record 1 of Set 4 | gogrial
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=torbay
# Processing Record 2 of Set 4 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hobart
# Processing Record 3 of Set 4 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=east+london
# Processing Record 4 of Set 4 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=oranjemund
# Processing Record 5 of Set 4 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=arraial+do+cabo
# Processing Record 6 of Set 4 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=camacha
# Processing Record 7 of Set 4 | camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=saint-philippe
# Processing Record 8 of Set 4 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=busselton
# Processing Record 9 of Set 4 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=amderma
# Processing Record 10 of Set 4 | amderma
# 'coord'
# City not found. Skipping...amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=bathsheba
# Processing Record 11 of Set 4 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kinsale
# Processing Record 12 of Set 4 | kinsale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=beringovskiy
# Processing Record 13 of Set 4 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=illoqqortoormiut
# Processing Record 14 of Set 4 | illoqqortoormiut
# 'coord'
# City not found. Skipping...illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=belushya+guba
# Processing Record 15 of Set 4 | belushya guba
# 'coord'
# City not found. Skipping...belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kapaa
# Processing Record 16 of Set 4 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=taolanaro
# Processing Record 17 of Set 4 | taolanaro
# 'coord'
# City not found. Skipping...taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=butaritari
# Processing Record 18 of Set 4 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=lata
# Processing Record 19 of Set 4 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=springbok
# Processing Record 20 of Set 4 | springbok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=havre-saint-pierre
# Processing Record 21 of Set 4 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=makakilo+city
# Processing Record 22 of Set 4 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=bredasdorp
# Processing Record 23 of Set 4 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=lompoc
# Processing Record 24 of Set 4 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=tsihombe
# Processing Record 25 of Set 4 | tsihombe
# 'coord'
# City not found. Skipping...tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=attawapiskat
# Processing Record 26 of Set 4 | attawapiskat
# 'coord'
# City not found. Skipping...attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=mys+shmidta
# Processing Record 27 of Set 4 | mys shmidta
# 'coord'
# City not found. Skipping...mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=bredasdorp
# Processing Record 28 of Set 4 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=jamestown
# Processing Record 29 of Set 4 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hobyo
# Processing Record 30 of Set 4 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=esperance
# Processing Record 31 of Set 4 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kathu
# Processing Record 32 of Set 4 | kathu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=tarauaca
# Processing Record 33 of Set 4 | tarauaca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=rikitea
# Processing Record 34 of Set 4 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=yeppoon
# Processing Record 35 of Set 4 | yeppoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=ulaangom
# Processing Record 36 of Set 4 | ulaangom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=esil
# Processing Record 37 of Set 4 | esil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=punta+arenas
# Processing Record 38 of Set 4 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kodiak
# Processing Record 39 of Set 4 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=vila+franca+do+campo
# Processing Record 40 of Set 4 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=atuona
# Processing Record 41 of Set 4 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=necochea
# Processing Record 42 of Set 4 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=tiznit
# Processing Record 43 of Set 4 | tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=avarua
# Processing Record 44 of Set 4 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=batagay-alyta
# Processing Record 45 of Set 4 | batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=ushuaia
# Processing Record 46 of Set 4 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=minnedosa
# Processing Record 47 of Set 4 | minnedosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=puri
# Processing Record 48 of Set 4 | puri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=andalan
# Processing Record 49 of Set 4 | andalan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=arraial+do+cabo
# Processing Record 50 of Set 4 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=foso
# Processing Record 1 of Set 5 | foso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=vada
# Processing Record 2 of Set 5 | vada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=punta+arenas
# Processing Record 3 of Set 5 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=jamestown
# Processing Record 4 of Set 5 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kasungu
# Processing Record 5 of Set 5 | kasungu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kendari
# Processing Record 6 of Set 5 | kendari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kirakira
# Processing Record 7 of Set 5 | kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=busselton
# Processing Record 8 of Set 5 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=tokur
# Processing Record 9 of Set 5 | tokur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=marawi
# Processing Record 10 of Set 5 | marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=griffith
# Processing Record 11 of Set 5 | griffith
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=ushuaia
# Processing Record 12 of Set 5 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=thompson
# Processing Record 13 of Set 5 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=taolanaro
# Processing Record 14 of Set 5 | taolanaro
# 'coord'
# City not found. Skipping...taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=busselton
# Processing Record 15 of Set 5 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=ushuaia
# Processing Record 16 of Set 5 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=lagoa
# Processing Record 17 of Set 5 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=camocim
# Processing Record 18 of Set 5 | camocim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=puerto+ayora
# Processing Record 19 of Set 5 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=vygonichi
# Processing Record 20 of Set 5 | vygonichi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=mataura
# Processing Record 21 of Set 5 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=puerto+baquerizo+moreno
# Processing Record 22 of Set 5 | puerto baquerizo moreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=mar+del+plata
# Processing Record 23 of Set 5 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=khorramshahr
# Processing Record 24 of Set 5 | khorramshahr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=arraial+do+cabo
# Processing Record 25 of Set 5 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=puerto+ayora
# Processing Record 26 of Set 5 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=east+london
# Processing Record 27 of Set 5 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=punta+arenas
# Processing Record 28 of Set 5 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=butaritari
# Processing Record 29 of Set 5 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=faanui
# Processing Record 30 of Set 5 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=mataura
# Processing Record 31 of Set 5 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=nizhneyansk
# Processing Record 32 of Set 5 | nizhneyansk
# 'coord'
# City not found. Skipping...nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=port+alfred
# Processing Record 33 of Set 5 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=richards+bay
# Processing Record 34 of Set 5 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=cap-aux-meules
# Processing Record 35 of Set 5 | cap-aux-meules
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=qaanaaq
# Processing Record 36 of Set 5 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=viedma
# Processing Record 37 of Set 5 | viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=halifax
# Processing Record 38 of Set 5 | halifax
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=georgetown
# Processing Record 39 of Set 5 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=albany
# Processing Record 40 of Set 5 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=talnakh
# Processing Record 41 of Set 5 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=qasigiannguit
# Processing Record 42 of Set 5 | qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=belushya+guba
# Processing Record 43 of Set 5 | belushya guba
# 'coord'
# City not found. Skipping...belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=chuy
# Processing Record 44 of Set 5 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hithadhoo
# Processing Record 45 of Set 5 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=narsaq
# Processing Record 46 of Set 5 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=new+norfolk
# Processing Record 47 of Set 5 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hobart
# Processing Record 48 of Set 5 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=barrow
# Processing Record 49 of Set 5 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=mataya
# Processing Record 50 of Set 5 | mataya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=dikson
# Processing Record 1 of Set 6 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=barrow
# Processing Record 2 of Set 6 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=socastee
# Processing Record 3 of Set 6 | socastee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=puerto+ayora
# Processing Record 4 of Set 6 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hithadhoo
# Processing Record 5 of Set 6 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=mataura
# Processing Record 6 of Set 6 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hamilton
# Processing Record 7 of Set 6 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=thompson
# Processing Record 8 of Set 6 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=bintulu
# Processing Record 9 of Set 6 | bintulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=ushuaia
# Processing Record 10 of Set 6 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=awjilah
# Processing Record 11 of Set 6 | awjilah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=port+elizabeth
# Processing Record 12 of Set 6 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=ushuaia
# Processing Record 13 of Set 6 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=gabu
# Processing Record 14 of Set 6 | gabu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=severo-kurilsk
# Processing Record 15 of Set 6 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=saleaula
# Processing Record 16 of Set 6 | saleaula
# 'coord'
# City not found. Skipping...saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=albany
# Processing Record 17 of Set 6 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=rikitea
# Processing Record 18 of Set 6 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=illoqqortoormiut
# Processing Record 19 of Set 6 | illoqqortoormiut
# 'coord'
# City not found. Skipping...illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=salalah
# Processing Record 20 of Set 6 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=high+prairie
# Processing Record 21 of Set 6 | high prairie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=bhum
# Processing Record 22 of Set 6 | bhum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=jamestown
# Processing Record 23 of Set 6 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=tuktoyaktuk
# Processing Record 24 of Set 6 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=betanzos
# Processing Record 25 of Set 6 | betanzos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=punta+arenas
# Processing Record 26 of Set 6 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=punta+arenas
# Processing Record 27 of Set 6 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=tczew
# Processing Record 28 of Set 6 | tczew
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=mataura
# Processing Record 29 of Set 6 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=sitka
# Processing Record 30 of Set 6 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=dikson
# Processing Record 31 of Set 6 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=cherskiy
# Processing Record 32 of Set 6 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=caucaia
# Processing Record 33 of Set 6 | caucaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=yellowknife
# Processing Record 34 of Set 6 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=tateyama
# Processing Record 35 of Set 6 | tateyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=mawlamyine
# Processing Record 36 of Set 6 | mawlamyine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=rikitea
# Processing Record 37 of Set 6 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=bambous+virieux
# Processing Record 38 of Set 6 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=cape+town
# Processing Record 39 of Set 6 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=albany
# Processing Record 40 of Set 6 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=port+elizabeth
# Processing Record 41 of Set 6 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=guerrero+negro
# Processing Record 42 of Set 6 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hasaki
# Processing Record 43 of Set 6 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=saint+george
# Processing Record 44 of Set 6 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=ushuaia
# Processing Record 45 of Set 6 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=petropavlovsk-kamchatskiy
# Processing Record 46 of Set 6 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kikwit
# Processing Record 47 of Set 6 | kikwit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=bathsheba
# Processing Record 48 of Set 6 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=mataura
# Processing Record 49 of Set 6 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=yashkul
# Processing Record 50 of Set 6 | yashkul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=butaritari
# Processing Record 1 of Set 7 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=pingyin
# Processing Record 2 of Set 7 | pingyin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hobart
# Processing Record 3 of Set 7 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=huarmey
# Processing Record 4 of Set 7 | huarmey
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=yenagoa
# Processing Record 50 of Set 8 | yenagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kapaa
# Processing Record 1 of Set 9 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kudahuvadhoo
# Processing Record 2 of Set 9 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=souillac
# Processing Record 3 of Set 9 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=albany
# Processing Record 4 of Set 9 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=vaini
# Processing Record 5 of Set 9 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=new+norfolk
# Processing Record 6 of Set 9 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=xinmin
# Processing Record 7 of Set 9 | xinmin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=lagoa
# Processing Record 8 of Set 9 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=boyolangu
# Processing Record 9 of Set 9 | boyolangu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=punta+arenas
# Processing Record 10 of Set 9 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hobart
# Processing Record 11 of Set 9 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=vaini
# Processing Record 12 of Set 9 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=albany
# Processing Record 13 of Set 9 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=chokurdakh
# Processing Record 14 of Set 9 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=rikitea
# Processing Record 15 of Set 9 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=saskylakh
# Processing Record 16 of Set 9 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=fare
# Processing Record 17 of Set 9 | fare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=orlik
# Processing Record 18 of Set 9 | orlik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=samalaeulu
# Processing Record 19 of Set 9 | samalaeulu
# 'coord'
# City not found. Skipping...samalaeulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=ridgecrest
# Processing Record 20 of Set 9 | ridgecrest
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kodiak
# Processing Record 21 of Set 9 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hamilton
# Processing Record 22 of Set 9 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=atuona
# Processing Record 23 of Set 9 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=elk+plain
# Processing Record 24 of Set 9 | elk plain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=butaritari
# Processing Record 25 of Set 9 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hilo
# Processing Record 26 of Set 9 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=vaini
# Processing Record 27 of Set 9 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=nizhneyansk
# Processing Record 28 of Set 9 | nizhneyansk
# 'coord'
# City not found. Skipping...nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=cherskiy
# Processing Record 29 of Set 9 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=rikitea
# Processing Record 30 of Set 9 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=nizhneyansk
# Processing Record 31 of Set 9 | nizhneyansk
# 'coord'
# City not found. Skipping...nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=new+norfolk
# Processing Record 32 of Set 9 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kapaa
# Processing Record 33 of Set 9 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hobart
# Processing Record 34 of Set 9 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=torbay
# Processing Record 35 of Set 9 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=palabuhanratu
# Processing Record 36 of Set 9 | palabuhanratu
# 'coord'
# City not found. Skipping...palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=punta+arenas
# Processing Record 37 of Set 9 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=barrow
# Processing Record 38 of Set 9 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=provideniya
# Processing Record 39 of Set 9 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kamskiye+polyany
# Processing Record 40 of Set 9 | kamskiye polyany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=santa+maria
# Processing Record 41 of Set 9 | santa maria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=caravelas
# Processing Record 42 of Set 9 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=camacha
# Processing Record 43 of Set 9 | camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=atuona
# Processing Record 44 of Set 9 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=new+norfolk
# Processing Record 45 of Set 9 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=sorvag
# Processing Record 46 of Set 9 | sorvag
# 'coord'
# City not found. Skipping...sorvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hobart
# Processing Record 47 of Set 9 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=tabou
# Processing Record 48 of Set 9 | tabou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=east+london
# Processing Record 49 of Set 9 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=radviliskis
# Processing Record 50 of Set 9 | radviliskis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=ushuaia
# Processing Record 1 of Set 10 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=koulamoutou
# Processing Record 2 of Set 10 | koulamoutou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=saint-augustin
# Processing Record 3 of Set 10 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=atuona
# Processing Record 4 of Set 10 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=vila+franca+do+campo
# Processing Record 5 of Set 10 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=phangnga
# Processing Record 6 of Set 10 | phangnga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=rousinov
# Processing Record 7 of Set 10 | rousinov
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=barrow
# Processing Record 8 of Set 10 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=mataura
# Processing Record 9 of Set 10 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=adrar
# Processing Record 10 of Set 10 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=avarua
# Processing Record 11 of Set 10 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=nanortalik
# Processing Record 12 of Set 10 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=lagoa
# Processing Record 13 of Set 10 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=punta+arenas
# Processing Record 14 of Set 10 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=barrow
# Processing Record 15 of Set 10 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kavaratti
# Processing Record 16 of Set 10 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hokitika
# Processing Record 17 of Set 10 | hokitika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=albany
# Processing Record 18 of Set 10 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=mataura
# Processing Record 19 of Set 10 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=taoudenni
# Processing Record 20 of Set 10 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=jamestown
# Processing Record 21 of Set 10 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=quatre+cocos
# Processing Record 22 of Set 10 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=aklavik
# Processing Record 23 of Set 10 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=quatre+cocos
# Processing Record 24 of Set 10 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=taolanaro
# Processing Record 25 of Set 10 | taolanaro
# 'coord'
# City not found. Skipping...taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=adrar
# Processing Record 26 of Set 10 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=atuona
# Processing Record 27 of Set 10 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=qingyuan
# Processing Record 28 of Set 10 | qingyuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=georgetown
# Processing Record 29 of Set 10 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=palafrugell
# Processing Record 30 of Set 10 | palafrugell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=thompson
# Processing Record 31 of Set 10 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kruisfontein
# Processing Record 32 of Set 10 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=eganville
# Processing Record 33 of Set 10 | eganville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=aguilas
# Processing Record 34 of Set 10 | aguilas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=upernavik
# Processing Record 35 of Set 10 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=vardo
# Processing Record 36 of Set 10 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=la+romana
# Processing Record 37 of Set 10 | la romana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=port-gentil
# Processing Record 38 of Set 10 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=punta+arenas
# Processing Record 39 of Set 10 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=upata
# Processing Record 40 of Set 10 | upata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=qaanaaq
# Processing Record 41 of Set 10 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hervey+bay
# Processing Record 42 of Set 10 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=nome
# Processing Record 43 of Set 10 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=rikitea
# Processing Record 44 of Set 10 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=hobart
# Processing Record 45 of Set 10 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=krasnoselkup
# Processing Record 46 of Set 10 | krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=kose-uuemoisa
# Processing Record 47 of Set 10 | kose-uuemoisa
# 'coord'
# City not found. Skipping...kose-uuemoisa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=havelock
# Processing Record 48 of Set 10 | havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=qaanaaq
# Processing Record 49 of Set 10 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da251a7ee9136a5d76166634a5973d6&q=khatanga
# Processing Record 50 of Set 10 | khatanga
# -----------------------------
# Data Retrieval Complete
# -----------------------------
